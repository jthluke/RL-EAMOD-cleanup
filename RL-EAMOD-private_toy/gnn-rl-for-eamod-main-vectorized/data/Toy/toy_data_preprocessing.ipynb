# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
# new special toy problem
new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 30
for i in range(episode_length):
    if i < 10:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 2
        attr['demand'] = 25.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 2
        attr['demand'] = 25.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)
    elif 10<=i<20:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 0
        attr['demand'] = 2.0
        attr['price'] = 5.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 1
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 2
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 0
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 1
        attr['demand'] = 2.0
        attr['price'] = 5.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 2
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 0
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 1
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 2
        attr['demand'] = 2.0
        attr['price'] = 5.0
        new_tripAttr.append(attr)
    else:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 0
        attr['demand'] = 25.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 1
        attr['demand'] = 25.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 0
    reb['destination'] = 1
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 0
    reb['destination'] = 2
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 0
    reb['destination'] = 0
    reb['reb_time'] = 1.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 1
    reb['destination'] = 0
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 1
    reb['destination'] = 2
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 1
    reb['destination'] = 1
    reb['reb_time'] = 1.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 2
    reb['destination'] = 1
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 2
    reb['destination'] = 0
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 2
    reb['destination'] = 2
    reb['reb_time'] = 1.0
    new_reb_time.append(reb)

    

for hour in range(30):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 210
    new_total_acc.append(acc)

number_chargelevels = 32
number_spatial_nodes = 3
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
# for i in range(number_spatial_nodes):
#     energy_distance[i,i] = 1
np.save('energy_distance_artificial.npy', energy_distance)
charge_time_per_delta_c = 1
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spatialNodes'] = number_spatial_nodes
new_data['chargeTime'] = charge_time_per_delta_c
new_data['episodeLength'] = episode_length
new_data["timeGranularity"] = 1
new_data['carsPerStationCapacity'] = (np.ones(number_spatial_nodes)*10000).tolist()
new_data["energy_prices"] = (np.ones(episode_length)*0.5).tolist()
new_data['chargeLevelsPerChargeStep'] = 30
new_data['chargeLocations'] = np.ones(number_spatial_nodes, dtype=bool).tolist()
new_data['operationalCostPerTimestep'] = 0.5

with open('scenario_artificial.json', 'w') as f:
    json.dump(new_data, f)

# test set 
new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 30
for i in range(episode_length):
    if i < 10:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 2
        attr['demand'] = 25.0 *0.9
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 2
        attr['demand'] = 25.0 *0.9
        attr['price'] = 10.0
        new_tripAttr.append(attr)
    elif 10<=i<20:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 0
        attr['demand'] = 2.0
        attr['price'] = 5.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 1
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 2
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 0
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 1
        attr['demand'] = 2.0
        attr['price'] = 5.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 2
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 0
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 1
        attr['demand'] = 2.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 2
        attr['demand'] = 2.0
        attr['price'] = 5.0
        new_tripAttr.append(attr)
    else:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 0
        attr['demand'] = 25.0 *0.9
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 2
        attr['destination'] = 1
        attr['demand'] = 25.0 *0.9
        attr['price'] = 10.0
        new_tripAttr.append(attr)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 0
    reb['destination'] = 1
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 0
    reb['destination'] = 2
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 0
    reb['destination'] = 0
    reb['reb_time'] = 1.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 1
    reb['destination'] = 0
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 1
    reb['destination'] = 2
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 1
    reb['destination'] = 1
    reb['reb_time'] = 1.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 2
    reb['destination'] = 1
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 2
    reb['destination'] = 0
    reb['reb_time'] = 2.0
    new_reb_time.append(reb)

    reb = defaultdict()
    reb['time_stamp'] = i
    reb['origin'] = 2
    reb['destination'] = 2
    reb['reb_time'] = 1.0
    new_reb_time.append(reb)

    

for hour in range(30):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 210
    new_total_acc.append(acc)

number_chargelevels = 32
number_spatial_nodes = 3
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
# for i in range(number_spatial_nodes):
#     energy_distance[i,i] = 1
np.save('energy_distance_artificial.npy', energy_distance)
charge_time_per_delta_c = 1
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spatialNodes'] = number_spatial_nodes
new_data['chargeTime'] = charge_time_per_delta_c
new_data['episodeLength'] = episode_length
new_data["timeGranularity"] = 1
new_data['carsPerStationCapacity'] = (np.ones(number_spatial_nodes)*10000).tolist()
new_data["energy_prices"] = (np.ones(episode_length)*0.5).tolist()
new_data['chargeLevelsPerChargeStep'] = 30
new_data['chargeLocations'] = np.ones(number_spatial_nodes, dtype=bool).tolist()
new_data['operationalCostPerTimestep'] = 0.5

with open('scenario_artificial_test.json', 'w') as f:
    json.dump(new_data, f)

# %%
# simple 2 nodes: 0 -> 1
new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 30
for i in range(episode_length):
    attr = defaultdict()
    attr['time_stamp'] = i
    attr['origin'] = 0
    attr['destination'] = 1
    attr['demand'] = 100.0
    attr['price'] = 10.0
    new_tripAttr.append(attr)

    reb1 = defaultdict()
    reb1['time_stamp'] = i
    reb1['origin'] = 0
    reb1['destination'] = 1
    reb1['reb_time'] = 1.0
    new_reb_time.append(reb1)

    reb2 = defaultdict()
    reb2['time_stamp'] = i
    reb2['origin'] = 1
    reb2['destination'] = 0
    reb2['reb_time'] = 1.0
    new_reb_time.append(reb2)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 0
    reb3['destination'] = 0
    reb3['reb_time'] = 0.0
    new_reb_time.append(reb3)

    reb4 = defaultdict()
    reb4['time_stamp'] = i
    reb4['origin'] = 1
    reb4['destination'] = 1
    reb4['reb_time'] = 0.0
    new_reb_time.append(reb4)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100
    new_total_acc.append(acc)

number_chargelevels = 5
number_spatial_nodes = 2
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_1x2.npy', energy_distance)
charge_time_per_delta_c = 1
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spacialNodes'] = number_spatial_nodes
new_data['chargeTime'] = charge_time_per_delta_c
new_data['episodeLength'] = episode_length

with open('scenario_train1x2.json', 'w') as f:
    json.dump(new_data, f)

new_data['chargelevels'] = 6
with open('scenario_test1x2.json', 'w') as f:
    json.dump(new_data, f)

# %%
# simple 1 nodes: 1 -> 1
new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 30
for i in range(episode_length):
    attr = defaultdict()
    attr['time_stamp'] = i
    attr['origin'] = 0
    attr['destination'] = 0
    attr['demand'] = 100.0
    attr['price'] = 10.0
    new_tripAttr.append(attr)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 0
    reb3['destination'] = 0
    reb3['reb_time'] = 1.0
    new_reb_time.append(reb3)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100
    new_total_acc.append(acc)

number_chargelevels = 5
number_spatial_nodes = 1
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_1x1.npy', energy_distance)
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spatialNodes'] = number_spatial_nodes
new_data['episodeLength'] = episode_length
new_data["timeGranularity"] = 1
new_data['carsPerStationCapacity'] = (np.ones(number_spatial_nodes)*1000).tolist()
new_data["energy_prices"] = (np.ones(episode_length)*0.5).tolist()
new_data['chargeLevelsPerChargeStep'] = 4
new_data['chargeLocations'] = np.ones(number_spatial_nodes, dtype=bool).tolist()
new_data['operationalCostPerTimestep'] = 0.5

with open('scenario_train1x1.json', 'w') as f:
    json.dump(new_data, f)

# simple 1 nodes: 1 -> 1 Test
new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 30
for i in range(episode_length):
    attr = defaultdict()
    attr['time_stamp'] = i
    attr['origin'] = 0
    attr['destination'] = 0
    attr['demand'] = 90.0
    attr['price'] = 10.0
    new_tripAttr.append(attr)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 0
    reb3['destination'] = 0
    reb3['reb_time'] = 1.0
    new_reb_time.append(reb3)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100
    new_total_acc.append(acc)

number_chargelevels = 5
number_spatial_nodes = 1
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_1x1.npy', energy_distance)
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spatialNodes'] = number_spatial_nodes
new_data['episodeLength'] = episode_length
new_data["timeGranularity"] = 1
new_data['carsPerStationCapacity'] = (np.ones(number_spatial_nodes)*1000).tolist()
new_data["energy_prices"] = (np.ones(episode_length)*0.5).tolist()
new_data['chargeLevelsPerChargeStep'] = 4
new_data['chargeLocations'] = np.ones(number_spatial_nodes, dtype=bool).tolist()
new_data['operationalCostPerTimestep'] = 0.5

new_data['chargelevels'] = 6
with open('scenario_test1x1.json', 'w') as f:
    json.dump(new_data, f)

# %%
# simple 2 nodes: 0 -> 1 with flip to 1 -> 0
new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 20
for i in range(episode_length):
    if i <episode_length/2:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 1
        attr['demand'] = 100.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)
    else:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 0
        attr['demand'] = 100.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)
    reb1 = defaultdict()
    reb1['time_stamp'] = i
    reb1['origin'] = 0
    reb1['destination'] = 1
    reb1['reb_time'] = 1.0
    new_reb_time.append(reb1)

    reb2 = defaultdict()
    reb2['time_stamp'] = i
    reb2['origin'] = 1
    reb2['destination'] = 0
    reb2['reb_time'] = 1.0
    new_reb_time.append(reb2)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 0
    reb3['destination'] = 0
    reb3['reb_time'] = 1.0
    new_reb_time.append(reb3)

    reb4 = defaultdict()
    reb4['time_stamp'] = i
    reb4['origin'] = 1
    reb4['destination'] = 1
    reb4['reb_time'] = 1.0
    new_reb_time.append(reb4)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100
    new_total_acc.append(acc)

number_chargelevels = 5
number_spatial_nodes = 2
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_1x2.npy', energy_distance)
charge_time_per_delta_c = 1
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spatialNodes'] = number_spatial_nodes
new_data['chargeTime'] = charge_time_per_delta_c
new_data['episodeLength'] = episode_length
new_data["timeGranularity"] = 1
new_data['carsPerStationCapacity'] = (np.ones(number_spatial_nodes)*1000).tolist()
new_data["energy_prices"] = (np.ones(episode_length)*0.5).tolist()
new_data['chargeLevelsPerChargeStep'] = 4
new_data['chargeLocations'] = np.ones(number_spatial_nodes, dtype=bool).tolist()
new_data['operationalCostPerTimestep'] = 0.5

with open('scenario_train1x2_flip.json', 'w') as f:
    json.dump(new_data, f)


new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 20
for i in range(episode_length):
    if i >=episode_length/2:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 1
        attr['demand'] = 50.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)
    else:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 1
        attr['destination'] = 0
        attr['demand'] = 50.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)
    reb1 = defaultdict()
    reb1['time_stamp'] = i
    reb1['origin'] = 0
    reb1['destination'] = 1
    reb1['reb_time'] = 1.0
    new_reb_time.append(reb1)

    reb2 = defaultdict()
    reb2['time_stamp'] = i
    reb2['origin'] = 1
    reb2['destination'] = 0
    reb2['reb_time'] = 1.0
    new_reb_time.append(reb2)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 0
    reb3['destination'] = 0
    reb3['reb_time'] = 1.0
    new_reb_time.append(reb3)

    reb4 = defaultdict()
    reb4['time_stamp'] = i
    reb4['origin'] = 1
    reb4['destination'] = 1
    reb4['reb_time'] = 1.0
    new_reb_time.append(reb4)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100
    new_total_acc.append(acc)

number_chargelevels = 5
number_spatial_nodes = 2
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_1x2.npy', energy_distance)
charge_time_per_delta_c = 1
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spatialNodes'] = number_spatial_nodes
new_data['chargeTime'] = charge_time_per_delta_c
new_data['episodeLength'] = episode_length
new_data["timeGranularity"] = 1
new_data['carsPerStationCapacity'] = (np.ones(number_spatial_nodes)*1000).tolist()
new_data["energy_prices"] = (np.ones(episode_length)*0.5).tolist()
new_data['chargeLevelsPerChargeStep'] = 4
new_data['chargeLocations'] = np.ones(number_spatial_nodes, dtype=bool).tolist()
new_data['operationalCostPerTimestep'] = 0.5

with open('scenario_test1x2_flip.json', 'w') as f:
    json.dump(new_data, f)

# %%
# 3 nodes: demand from 0->1 and 2->1
new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 20
for i in range(episode_length):
    attr = defaultdict()
    attr['time_stamp'] = i
    attr['origin'] = 0
    attr['destination'] = 1
    attr['demand'] = 50.0
    attr['price'] = 10.0
    new_tripAttr.append(attr)

    attr2 = defaultdict()
    attr2['time_stamp'] = i
    attr2['origin'] = 2
    attr2['destination'] = 1
    attr2['demand'] = 50.0
    attr2['price'] = 10.0
    new_tripAttr.append(attr2)

    reb1 = defaultdict()
    reb1['time_stamp'] = i
    reb1['origin'] = 0
    reb1['destination'] = 1
    reb1['reb_time'] = 1.0
    new_reb_time.append(reb1)

    reb2 = defaultdict()
    reb2['time_stamp'] = i
    reb2['origin'] = 0
    reb2['destination'] = 2
    reb2['reb_time'] = 1.0
    new_reb_time.append(reb2)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 1
    reb3['destination'] = 0
    reb3['reb_time'] = 1.0
    new_reb_time.append(reb3)

    reb4 = defaultdict()
    reb4['time_stamp'] = i
    reb4['origin'] = 1
    reb4['destination'] = 2
    reb4['reb_time'] = 1.0
    new_reb_time.append(reb4)

    reb5 = defaultdict()
    reb5['time_stamp'] = i
    reb5['origin'] = 2
    reb5['destination'] = 1
    reb5['reb_time'] = 1.0
    new_reb_time.append(reb5)

    reb6 = defaultdict()
    reb6['time_stamp'] = i
    reb6['origin'] = 2
    reb6['destination'] = 0
    reb6['reb_time'] = 1.0
    new_reb_time.append(reb6)

    reb7 = defaultdict()
    reb7['time_stamp'] = i
    reb7['origin'] = 0
    reb7['destination'] = 0
    reb7['reb_time'] = 1.0
    new_reb_time.append(reb7)

    reb8 = defaultdict()
    reb8['time_stamp'] = i
    reb8['origin'] = 1
    reb8['destination'] = 1
    reb8['reb_time'] = 1.0
    new_reb_time.append(reb8)

    reb9 = defaultdict()
    reb9['time_stamp'] = i
    reb9['origin'] = 2
    reb9['destination'] = 2
    reb9['reb_time'] = 1.0
    new_reb_time.append(reb9)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100
    new_total_acc.append(acc)
number_chargelevels = 5
number_spatial_nodes = 3
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spatialNodes'] = number_spatial_nodes
new_data['episodeLength'] = episode_length
new_data["timeGranularity"] = 1
new_data['carsPerStationCapacity'] = (np.ones(number_spatial_nodes)*1000).tolist()
new_data["energy_prices"] = (np.ones(episode_length)*0.5).tolist()
new_data['chargeLevelsPerChargeStep'] = 4
new_data['chargeLocations'] = np.ones(number_spatial_nodes, dtype=bool).tolist()
new_data['operationalCostPerTimestep'] = 0.5

with open('scenario_train_3_2.json', 'w') as f:
    json.dump(new_data, f)
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_3x2.npy', energy_distance)

new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 20
for i in range(episode_length):
    attr = defaultdict()
    attr['time_stamp'] = i
    attr['origin'] = 0
    attr['destination'] = 1
    attr['demand'] = 45.0
    attr['price'] = 10.0
    new_tripAttr.append(attr)

    attr2 = defaultdict()
    attr2['time_stamp'] = i
    attr2['origin'] = 2
    attr2['destination'] = 1
    attr2['demand'] = 45.0
    attr2['price'] = 10.0
    new_tripAttr.append(attr2)

    reb1 = defaultdict()
    reb1['time_stamp'] = i
    reb1['origin'] = 0
    reb1['destination'] = 1
    reb1['reb_time'] = 1.0
    new_reb_time.append(reb1)

    reb2 = defaultdict()
    reb2['time_stamp'] = i
    reb2['origin'] = 0
    reb2['destination'] = 2
    reb2['reb_time'] = 1.0
    new_reb_time.append(reb2)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 1
    reb3['destination'] = 0
    reb3['reb_time'] = 1.0
    new_reb_time.append(reb3)

    reb4 = defaultdict()
    reb4['time_stamp'] = i
    reb4['origin'] = 1
    reb4['destination'] = 2
    reb4['reb_time'] = 1.0
    new_reb_time.append(reb4)

    reb5 = defaultdict()
    reb5['time_stamp'] = i
    reb5['origin'] = 2
    reb5['destination'] = 1
    reb5['reb_time'] = 1.0
    new_reb_time.append(reb5)

    reb6 = defaultdict()
    reb6['time_stamp'] = i
    reb6['origin'] = 2
    reb6['destination'] = 0
    reb6['reb_time'] = 1.0
    new_reb_time.append(reb6)

    reb7 = defaultdict()
    reb7['time_stamp'] = i
    reb7['origin'] = 0
    reb7['destination'] = 0
    reb7['reb_time'] = 1.0
    new_reb_time.append(reb7)

    reb8 = defaultdict()
    reb8['time_stamp'] = i
    reb8['origin'] = 1
    reb8['destination'] = 1
    reb8['reb_time'] = 1.0
    new_reb_time.append(reb8)

    reb9 = defaultdict()
    reb9['time_stamp'] = i
    reb9['origin'] = 2
    reb9['destination'] = 2
    reb9['reb_time'] = 1.0
    new_reb_time.append(reb9)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100
    new_total_acc.append(acc)
number_chargelevels = 5
number_spatial_nodes = 3
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargelevels'] = number_chargelevels
new_data['spatialNodes'] = number_spatial_nodes
new_data['episodeLength'] = episode_length
new_data["timeGranularity"] = 1
new_data['carsPerStationCapacity'] = (np.ones(number_spatial_nodes)*1000).tolist()
new_data["energy_prices"] = (np.ones(episode_length)*0.5).tolist()
new_data['chargeLevelsPerChargeStep'] = 4
new_data['chargeLocations'] = np.ones(number_spatial_nodes, dtype=bool).tolist()
new_data['operationalCostPerTimestep'] = 0.5

with open('scenario_test_3_2.json', 'w') as f:
    json.dump(new_data, f)
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_3x2.npy', energy_distance)

# %%
# 3 nodes: demand from 0->1 and 1->2, and 2->0 sparse
new_tripAttr = []
new_reb_time = []
new_total_acc = []
episode_length = 30
for i in range(episode_length):
    if i % 5 == 0:
        attr = defaultdict()
        attr['time_stamp'] = i
        attr['origin'] = 0
        attr['destination'] = 1
        attr['demand'] = 33.0
        attr['price'] = 10.0
        new_tripAttr.append(attr)

        attr2 = defaultdict()
        attr2['time_stamp'] = i
        attr2['origin'] = 1
        attr2['destination'] = 2
        attr2['demand'] = 33.0
        attr2['price'] = 10.0
        new_tripAttr.append(attr2)

        attr2 = defaultdict()
        attr2['time_stamp'] = i
        attr2['origin'] = 2
        attr2['destination'] = 0
        attr2['demand'] = 33.0
        attr2['price'] = 10.0
        new_tripAttr.append(attr2)

    reb1 = defaultdict()
    reb1['time_stamp'] = i
    reb1['origin'] = 0
    reb1['destination'] = 1
    reb1['reb_time'] = 1.0
    new_reb_time.append(reb1)

    reb2 = defaultdict()
    reb2['time_stamp'] = i
    reb2['origin'] = 0
    reb2['destination'] = 2
    reb2['reb_time'] = 1.0
    new_reb_time.append(reb2)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 1
    reb3['destination'] = 0
    reb3['reb_time'] = 1.0
    new_reb_time.append(reb3)

    reb4 = defaultdict()
    reb4['time_stamp'] = i
    reb4['origin'] = 1
    reb4['destination'] = 2
    reb4['reb_time'] = 1.0
    new_reb_time.append(reb4)

    reb5 = defaultdict()
    reb5['time_stamp'] = i
    reb5['origin'] = 2
    reb5['destination'] = 1
    reb5['reb_time'] = 1.0
    new_reb_time.append(reb5)

    reb6 = defaultdict()
    reb6['time_stamp'] = i
    reb6['origin'] = 2
    reb6['destination'] = 0
    reb6['reb_time'] = 1.0
    new_reb_time.append(reb6)

    reb7 = defaultdict()
    reb7['time_stamp'] = i
    reb7['origin'] = 0
    reb7['destination'] = 0
    reb7['reb_time'] = 1.0
    new_reb_time.append(reb7)

    reb8 = defaultdict()
    reb8['time_stamp'] = i
    reb8['origin'] = 1
    reb8['destination'] = 1
    reb8['reb_time'] = 1.0
    new_reb_time.append(reb8)

    reb9 = defaultdict()
    reb9['time_stamp'] = i
    reb9['origin'] = 2
    reb9['destination'] = 2
    reb9['reb_time'] = 1.0
    new_reb_time.append(reb9)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100
    new_total_acc.append(acc)
number_chargelevels = 4
number_spatial_nodes = 3
charge_time_per_delta_c = 1
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['chargelevels'] = number_chargelevels
new_data['spacialNodes'] = number_spatial_nodes
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargeTime'] = charge_time_per_delta_c
new_data['episodeLength'] = episode_length

with open('scenario_train_3_3.json', 'w') as f:
    json.dump(new_data, f)
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_3x3.npy', energy_distance)

# %%
# 3 nodes: upscaled demand from 0->1 and 2->1
new_tripAttr = []
new_reb_time = []
new_total_acc = []
for i in range(180):
    
    attr = defaultdict()
    attr['time_stamp'] = i
    attr['origin'] = 0
    attr['destination'] = 1
    attr['demand'] = 20.e10
    attr['price'] = 100.0
    new_tripAttr.append(attr)

    attr2 = defaultdict()
    attr2['time_stamp'] = i
    attr2['origin'] = 2
    attr2['destination'] = 1
    attr2['demand'] = 20.e10
    attr2['price'] = 100.0
    new_tripAttr.append(attr2)

    reb1 = defaultdict()
    reb1['time_stamp'] = i
    reb1['origin'] = 0
    reb1['destination'] = 1
    reb1['reb_time'] = 1.0
    new_reb_time.append(reb1)

    reb2 = defaultdict()
    reb2['time_stamp'] = i
    reb2['origin'] = 0
    reb2['destination'] = 2
    reb2['reb_time'] = 1.0
    new_reb_time.append(reb2)

    reb3 = defaultdict()
    reb3['time_stamp'] = i
    reb3['origin'] = 1
    reb3['destination'] = 0
    reb3['reb_time'] = 1.0
    new_reb_time.append(reb3)

    reb4 = defaultdict()
    reb4['time_stamp'] = i
    reb4['origin'] = 1
    reb4['destination'] = 2
    reb4['reb_time'] = 1.0
    new_reb_time.append(reb4)

    reb5 = defaultdict()
    reb5['time_stamp'] = i
    reb5['origin'] = 2
    reb5['destination'] = 1
    reb5['reb_time'] = 1.0
    new_reb_time.append(reb5)

    reb6 = defaultdict()
    reb6['time_stamp'] = i
    reb6['origin'] = 2
    reb6['destination'] = 0
    reb6['reb_time'] = 1.0
    new_reb_time.append(reb6)

    reb7 = defaultdict()
    reb7['time_stamp'] = i
    reb7['origin'] = 0
    reb7['destination'] = 0
    reb7['reb_time'] = 0.0
    new_reb_time.append(reb7)

    reb8 = defaultdict()
    reb8['time_stamp'] = i
    reb8['origin'] = 1
    reb8['destination'] = 1
    reb8['reb_time'] = 0.0
    new_reb_time.append(reb8)

    reb9 = defaultdict()
    reb9['time_stamp'] = i
    reb9['origin'] = 2
    reb9['destination'] = 2
    reb9['reb_time'] = 0.0
    new_reb_time.append(reb9)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = 100e10
    new_total_acc.append(acc)
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['chargelevels'] = number_chargelevels
new_data['spacialNodes'] = number_spatial_nodes
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc
new_data['chargeTime'] = charge_time_per_delta_c
new_data['episodeLength'] = episode_length

with open('scenario_test_super_upscaled_3_2.json', 'w') as f:
    json.dump(new_data, f)
energy_distance = np.ones((number_spatial_nodes,number_spatial_nodes))
np.save('energy_distance_3x2.npy', energy_distance)

# %%
# 10 nodes
new_tripAttr = []
new_reb_time = []
new_total_acc = []
number_nodes = 10
number_nodes_minus_one = number_nodes-1
for i in range(180):
    for node in range(number_nodes_minus_one):
        if i % 60 < 30:
            attr = defaultdict()
            attr['time_stamp'] = i
            attr['origin'] = node
            attr['destination'] = node+1
            attr['demand'] = 20.0
            attr['price'] = 100.0
            new_tripAttr.append(attr)
        else:
            attr = defaultdict()
            attr['time_stamp'] = i
            attr['origin'] = number_nodes_minus_one-node
            attr['destination'] = number_nodes_minus_one - (node+1)
            attr['demand'] = 20.0
            attr['price'] = 100.0
            new_tripAttr.append(attr)
    for o_node in range(number_nodes):
        for d_node in range(number_nodes):
            reb = defaultdict()
            reb['time_stamp'] = i
            reb['origin'] = o_node
            reb['destination'] = d_node
            reb['reb_time'] = abs(d_node-o_node)
            new_reb_time.append(reb)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = number_nodes*10
    new_total_acc.append(acc)
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc

with open('scenario_test1x10.json', 'w') as f:
    json.dump(new_data, f)

# %%
# random locations and demand
new_tripAttr = []
new_reb_time = []
new_total_acc = []
number_nodes = 3
np.random.seed(1)
possible_nodes = range(number_nodes)
origins = np.random.choice(possible_nodes, 2)
destinations = np.random.choice(possible_nodes, 2)
print(origins)
print(destinations)

for t in range(30):
    for origin,destination in zip(origins,destinations):
        attr = defaultdict()
        attr['time_stamp'] = t
        attr['origin'] = int(origin)
        attr['destination'] = int(destination)
        demand = int(abs(40*np.sin(((2.*np.pi) / 15.) * t)))
        attr['demand'] = demand
        attr['price'] = 100.0
        new_tripAttr.append(attr)
        
    for o_node in range(number_nodes):
        for d_node in range(number_nodes):
            reb = defaultdict()
            reb['time_stamp'] = t
            reb['origin'] = o_node
            reb['destination'] = d_node
            reb['reb_time'] = abs(d_node-o_node)
            new_reb_time.append(reb)

for hour in range(24):
    acc = defaultdict()
    acc['hour'] = hour
    acc['acc'] = number_nodes*100
    new_total_acc.append(acc)
new_data = defaultdict()
new_data['demand'] = new_tripAttr
new_data['rebTime'] = new_reb_time
new_data['totalAcc'] = new_total_acc

with open('scenario_test_random.json', 'w') as f:
    json.dump(new_data, f)
# Out:
# [1 0]
# [0 1]
